# %%
from cnn_model import TESSTransitCNN
# Out:
# It was impossible to set your directory as the current one because of the following message
# '__vsc_ipynb_file__'
# The working directory is:  /Users/bponnekanti/Computational/comp_astro_25/assignment2
# 2026-01-25 15:19:40.675957: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
# FINAL TESS CLASSIFICATION
# ...
# TF version: 2.16.2

# %%
cd run_tess_taskF/
# Out:
# /Users/bponnekanti/Computational/comp_astro_25/assignment2/run_tess_taskF

# %%
from run_tess_cnn_taskF import test_all_configurations

# %%
test_all_configurations()
# Out:
# ...
# TESTING CNN CONFIGURATIONS FOR TESS TRANSIT DETECTION
# ...
#
# ...
# STARTING TEST: Default
# ...
#
# ...
# LOADING DATA
# ...
# Dataset: 944 samples
#
# Original distribution:
#   Class 0: 472, Class 1: 472
#   Ratio: 1.00:1
#
# Initial split - Train: 755, Test: 189
#
# ...
# CREATING BALANCED DATASET
# ...
# Original - Class 0: 377, Class 1: 378
# Balanced - Class 0: 400, Class 1: 400
#
# ...
# STANDARDIZATION
# ...
# Train: mean=0.000000, std=1.000000
# Test:  mean=0.006526, std=0.401057
#
# Final - X_train: (800, 1000, 1), X_test: (189, 1000, 1)
# Train dist: 0=400, 1=400
#
# Default CNN Architecture:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 1000, 64)       │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...
