# %%
import matplotlib.pyplot as plt
# %matplotlib widget
from ipywidgets import *
import numpy as np
import sys

# %% [markdown]
# ## Creating a Randomized abundance for atmospheric elements for the parameter files

# %% [markdown]
# ### PART A

# %%
rng = np.random.default_rng(seed=100)

h20 = rng.uniform(1e-8,1e-2)
ch4 = rng.uniform(1e-8,1e-2)
co = rng.uniform(1e-8,1e-2)
co2 = rng.uniform(1e-8,1e-2)

# %%
h20
# Out:
# 0.008349817955203785

# %%
ch4
# Out:
# 0.005965544304138603

# %%
co
# Out:
# 0.002888639528279619

# %%
co2
# Out:
# 0.0004295252774264071
